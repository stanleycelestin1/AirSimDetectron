# %%
import setup_path 
import airsim

import time
import os
import numpy as np
import matplotlib.pyplot as plt

def write_file(filename, bstr):
    print(filename)
    with open(filename, 'wb') as afile:
        afile.write(bstr)

# connect to the AirSim simulator 
client = airsim.CarClient()
client.confirmConnection()
# Out:
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)

# %%
raw = client.simGetImages([airsim.ImageRequest("1", airsim.ImageType.Scene)])

# %%
im  = np.fromstring(raw[0].image_data_uint8, dtype=np.uint8)
print(type(raw[0].image_data_uint8))
# Out:
# <type 'str'>
# /home/t-stcele/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   """Entry point for launching an IPython kernel.

# %%
filename = '/tmp/pyTEST'

# %%
write_file(os.path.normpath(filename + '.png'), raw[0].image_data_uint8)
# Out:
# /tmp/pyTEST.png

# %%
im=plt.imread(filename+'.png')

# %%
print(im.shape)
plt.imshow(im)

plt.draw
# Out:
# (144, 256, 4)
# <function matplotlib.pyplot.draw>
